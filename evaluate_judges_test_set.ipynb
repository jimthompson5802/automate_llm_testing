# %% [markdown]
# # Evaluate Test Set with Automated Evaluation
#
# Based on Python package [`judges`](https://pypi.org/project/judges/)
#
# github repo: [`judges`](https://github.com/quotient-ai/judges)
#
# Blog post: [**Introducing judges: A Library of Research-Backed LLM-as-a-Judge Evaluators**](https://www.quotientai.co/post/introducing-judges-a-library-of-research-backed-llm-as-a-judge-evaluators)

# %%
import json
import pandas as pd
import random
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

from judges.graders.response_quality import MTBenchChatBotResponseQuality
from judges.graders.relevance import ReliableCIRelevance
from judges.classifiers.correctness import PollMultihopCorrectness

# %%
VECTOR_DB_FP = "vector_stores/vector_store_faiss_openai"
TEST_SET_FP = "test_sets/baseline_test_set.json"

# %%
# setup embeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
# establish the judge
judge_response_quality = MTBenchChatBotResponseQuality(model="gpt-4o")
# judge_relevance = ReliableCIRelevance(model="gpt-4o")   # causes error missing 'context' parameter
judge_correctness = PollMultihopCorrectness(model="gpt-4o")

judges = [judge_response_quality, judge_correctness]

# %%
# restore vector store
vector_store = FAISS.load_local(
    VECTOR_DB_FP, embeddings, allow_dangerous_deserialization=True
)

# %%
# retriev test set
with open(TEST_SET_FP, "r") as f:
    test_set = json.load(f)

test_set
# Out:
# [{'prompt': 'Provide a summary of space exploration',
#   'target_response': '## **The Future of Space Exploration: Colonizing Mars and Beyond**  \n\n### **Introduction**  \nSpace exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.  \n\n### **Milestones in Space Exploration**  \nThe Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.  \n\n### **Colonizing Mars**  \nMars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.  \n\n### **Beyond Mars: The Interstellar Future**  \nLong-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.  '},
#  {'prompt': 'Provide a summary of philosopy consciousness',
#   'target_response': '## **The Philosophy of Consciousness: Understanding the Mind**  \n\n### **Introduction**  \nConsciousness remains one of philosophy\'s greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.  \n\n### **Dualism vs. Materialism**  \nPhilosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.  \n\n### **Theories of Consciousness**  \n- **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing.  \n- **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions.  \n- **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.  \n\n### **Implications for AI and Ethics**  \nIf consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.  '},
#  {'prompt': 'Provide a summary of ancient civilizations',
#   'target_response': '## **The Legacy of Ancient Civilizations**  \n\n### **Introduction**  \nAncient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.  \n\n### **Mesopotamia: The Cradle of Civilization**  \nThe Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.  \n\n### **Ancient Egypt: Engineering and Spirituality**  \nThe Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.  \n\n### **Classical Greece and Rome**  \nGreek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.  \n\n### **The Maya and Other Pre-Columbian Civilizations**  \nThe Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.  \n\n### **Conclusion**  \nBy studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.  '},
#  {'prompt': 'Provide a summary of climate change',
#   'target_response': '## **Climate Change and the Future of the Planet**  \n\n### **Introduction**  \nClimate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.  \n\n### **Scientific Consensus and Causes**  \nOver 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.  \n\n### **Effects of Climate Change**  \n- Rising sea levels threaten coastal cities.  \n- More frequent wildfires, hurricanes, and droughts.  \n- Disruption of agriculture and food supplies.  \n- Loss of biodiversity and habitat destruction.  \n\n### **Mitigation and Solutions**  \nGovernments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.  '},
#  {'prompt': 'Provide a summary of artificial intelligence',
#   'target_response': '## **The Evolution and Future of Artificial Intelligence**  \n\n### **Introduction**  \nArtificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.  \n\n### **Historical Development**  \nAI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.  \n\n### **Modern Applications**  \nToday, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.  \n\n### **Ethical Concerns and Future Prospects**  \nAs AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.  '},
#  {'prompt': 'Provide a summary of vaccines',
#   'target_response': '### **Vaccines: A Key to Public Health**  \n\nVaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.  \n\nVaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.  \n\nVaccines not only safeguard individuals but also contribute to **herd immunity**, reducing the spread of diseases within communities. Widespread immunization efforts are crucial for preventing outbreaks and protecting vulnerable populations, including young children, the elderly, and those with weakened immune systems.  \n\nDespite their proven benefits, vaccine hesitancy remains a challenge, often fueled by misinformation. Public health organizations and medical professionals emphasize the importance of vaccines in maintaining global health and preventing severe illness.  \n\nIn conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.'}]

# %%
def evalutate_test_set(this_test_set, this_judge):
    # interate over the test set and retrieve similar chunks
    this_test_results = []
    for this_test_case in this_test_set:
        query = this_test_case["prompt"]
        relevant_chunks = vector_store.similarity_search(query, k=2)

        # Print retrieved chunks with source information
        print(f"\nQUERY: {query}, related material:")
        retrieved_data = "\n".join([chunk.page_content for chunk in relevant_chunks])
        print(f"\nRETRIEVED: {retrieved_data}")

        # judge the quality of the response
        target_response = this_test_case["target_response"]
        print(f"\nTARGET: {target_response}")
        quality = this_judge.judge(query, retrieved_data, target_response)
        print(f"\n>>>QUALITY: {quality}")

        this_test_result = quality.__dict__
        this_test_result.update(this_test_case)
        this_test_result["retrieved_data"] = retrieved_data

        this_test_results.append(this_test_result)

    return this_test_results

# %% [markdown]
# ## Baseline Test Set

# %%
for judge in judges:
    print(f"\n\n>>>Running test set evaluation for {judge.__class__.__name__}")
    test_results = evalutate_test_set(test_set, judge)
    test_df = pd.DataFrame(test_results)
    print(test_df.columns)
    # change order of columns
    test_df = test_df[
        [
            "prompt",
            "score",
            "retrieved_data",
            "target_response",
            "reasoning",
        ]
    ]
    test_df["judge"] = judge.__class__.__name__

    print(test_df)
# Out:
# >>>Running test set evaluation for MTBenchChatBotResponseQuality
#
# QUERY: Provide a summary of space exploration, related material:
#
# RETRIEVED: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction** Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration** The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
# ### **Colonizing Mars** Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future** Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# TARGET: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction**
# Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration**
# The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
#
# ### **Colonizing Mars**
# Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future**
# Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# >>>QUALITY: Judgment(score='7', reasoning="The assistant's response is structured, covering several aspects of space exploration, which gives a decent overview. The introduction sets the stage for the topic. The response then highlights significant historical milestones such as the first moon landing and the ISS, offering a concise context. It also discusses future potentials like Mars colonization, addressing key challenges and possible technological solutions. The mention of beyond-Mars exploration adds depth, showing foresight into potential advancements. However, the response might lack detailed exploration of current scientific missions or detailed geopolitical aspects of space exploration, which could have improved the response. Overall, the response is relevant and touches on different dimensions but does not fully cover the current state and breadth of space exploration.")
#
# QUERY: Provide a summary of philosopy consciousness, related material:
#
# RETRIEVED: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction** Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism** Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
# ### **Theories of Consciousness** - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing. - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions. - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics** If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# TARGET: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction**
# Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism**
# Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
#
# ### **Theories of Consciousness**
# - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing.
# - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions.
# - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics**
# If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# >>>QUALITY: Judgment(score='7', reasoning="The assistant's response provides a concise introduction to the philosophy of consciousness, touching on major philosophical positions such as dualism and materialism, as well as contemporary theories like Integrated Information Theory, Global Workspace Theory, and panpsychism. These elements encompass key debates and theories relevant to the philosophy of consciousness, showing good relevance and accuracy. However, while informative, the response lacks depth and exploration into how these theories interact or the nuances within each philosophical approach. Additionally, the section on implications for AI and ethics is only briefly mentioned without much detail or expansion on how these philosophical ideas might influence AI research or ethical considerations. Overall, the response covers important aspects but could be more detailed and critical in its analysis.")
#
# QUERY: Provide a summary of ancient civilizations, related material:
#
# RETRIEVED: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction** Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization** The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality** The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
# ### **Classical Greece and Rome** Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations** The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion** By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# TARGET: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction**
# Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization**
# The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality**
# The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
#
# ### **Classical Greece and Rome**
# Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations**
# The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion**
# By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# >>>QUALITY: Judgment(score='8', reasoning="The response provided by the AI assistant is well-structured and touches on several major ancient civilizations, including Mesopotamia, Ancient Egypt, Classical Greece and Rome, and Pre-Columbian civilizations such as the Maya, Inca, and Aztecs. Each section includes specific contributions made by these civilizations, demonstrating a level of depth and detail in relation to the user's inquiry. The response is written in a clear and organized manner, making it easily understandable. However, while the summary is informative, it could be further enriched with more specific examples or additional civilizations to provide a more comprehensive overview. The assistant effectively highlights the impact of these civilizations on modern society, showing relevance and helpfulness. Overall, the response is accurate and relevant, though there's room for expansion in certain areas for a more thorough exploration.")
#
# QUERY: Provide a summary of climate change, related material:
#
# RETRIEVED: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction** Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes** Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
# ### **Effects of Climate Change** - Rising sea levels threaten coastal cities. - More frequent wildfires, hurricanes, and droughts. - Disruption of agriculture and food supplies. - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions** Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# TARGET: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction**
# Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes**
# Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
#
# ### **Effects of Climate Change**
# - Rising sea levels threaten coastal cities.
# - More frequent wildfires, hurricanes, and droughts.
# - Disruption of agriculture and food supplies.
# - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions**
# Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# >>>QUALITY: Judgment(score='8', reasoning="The assistant's response provides a concise yet comprehensive overview of climate change. Its structure is clear and logical, beginning with an introduction that sets the context and importance of the issue. The response then outlines the scientific consensus on causes, illustrating the human activities contributing to climate change. The effects section effectively communicates the impact of these changes on the environment and society. In terms of mitigation, it mentions key strategies and international efforts to combat climate change, showing both current actions and the need for further measures. Overall, the response covers essential aspects of climate change with adequate depth, accuracy, and relevance. While the response is well-rounded, it could benefit from additional details on specific solutions or examples of successful initiatives to enhance depth and creativity.")
#
# QUERY: Provide a summary of artificial intelligence, related material:
#
# RETRIEVED: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction** Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development** AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
# ### **Modern Applications** Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects** As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# TARGET: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction**
# Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development**
# AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
#
# ### **Modern Applications**
# Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects**
# As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# >>>QUALITY: Judgment(score='8', reasoning="The AI assistant's response provides a well-structured and coherent summary of artificial intelligence. The introduction effectively outlines AI's transition from an academic pursuit to a central technological force. The historical development section succinctly traces AI's evolution from Alan Turing's early work to the rise of deep learning, offering a clear timeline. Modern applications of AI are accurately described, highlighting its widespread use in various industries. The inclusion of ethical concerns and future prospects addresses some of the central issues and potential developments within the AI field. However, while the response is informative and covers multiple aspects, it could benefit from more depth in detailing specific AI technologies and methodologies. Additionally, the coverage of ethical concerns could be expanded to include more concrete examples. Overall, the response is highly relevant, creative in its structure, and provides a good level of detail.")
#
# QUERY: Provide a summary of vaccines, related material:
#
# RETRIEVED: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# TARGET: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
#
# Vaccines not only safeguard individuals but also contribute to **herd immunity**, reducing the spread of diseases within communities. Widespread immunization efforts are crucial for preventing outbreaks and protecting vulnerable populations, including young children, the elderly, and those with weakened immune systems.
#
# Despite their proven benefits, vaccine hesitancy remains a challenge, often fueled by misinformation. Public health organizations and medical professionals emphasize the importance of vaccines in maintaining global health and preventing severe illness.
#
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# >>>QUALITY: Judgment(score='8', reasoning="The assistant's response provides a concise and clear overview of vaccines, highlighting their purpose, mechanisms, and impact on public health. It mentions the essential components and types of vaccines, such as weakened or inactivated pathogens, which is relevant and accurate. The historical and modern significance of vaccines is emphasized, and examples like polio, smallpox, and COVID-19 contribute to the response's depth and relevance. However, the response could include more detailed information about different types of vaccines and their specific uses, as well as mention potential challenges or controversies related to vaccination. Overall, it effectively introduces the topic with sufficient detail and accuracy for a general understanding.")
# Index(['score', 'reasoning', 'prompt', 'target_response', 'retrieved_data'], dtype='object')
#                                          prompt score  \
# 0        Provide a summary of space exploration     7
# 1  Provide a summary of philosopy consciousness     7
# 2    Provide a summary of ancient civilizations     8
# 3           Provide a summary of climate change     8
# 4  Provide a summary of artificial intelligence     8
# 5                 Provide a summary of vaccines     8
#
#                                       retrieved_data  \
# 0  ## **The Future of Space Exploration: Colonizi...
# 1  ## **The Philosophy of Consciousness: Understa...
# 2  ## **The Legacy of Ancient Civilizations**\n\n...
# 3  ## **Climate Change and the Future of the Plan...
# 4  ## **The Evolution and Future of Artificial In...
# 5  ### **Vaccines: A Key to Public Health**\n\nVa...
#
#                                      target_response  \
# 0  ## **The Future of Space Exploration: Colonizi...
# 1  ## **The Philosophy of Consciousness: Understa...
# 2  ## **The Legacy of Ancient Civilizations**  \n...
# 3  ## **Climate Change and the Future of the Plan...
# 4  ## **The Evolution and Future of Artificial In...
# 5  ### **Vaccines: A Key to Public Health**  \n\n...
#
#                                            reasoning  \
# 0  The assistant's response is structured, coveri...
# 1  The assistant's response provides a concise in...
# 2  The response provided by the AI assistant is w...
# 3  The assistant's response provides a concise ye...
# 4  The AI assistant's response provides a well-st...
# 5  The assistant's response provides a concise an...
#
#                            judge
# 0  MTBenchChatBotResponseQuality
# 1  MTBenchChatBotResponseQuality
# 2  MTBenchChatBotResponseQuality
# 3  MTBenchChatBotResponseQuality
# 4  MTBenchChatBotResponseQuality
# 5  MTBenchChatBotResponseQuality
#
#
# >>>Running test set evaluation for PollMultihopCorrectness
#
# QUERY: Provide a summary of space exploration, related material:
#
# RETRIEVED: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction** Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration** The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
# ### **Colonizing Mars** Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future** Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# TARGET: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction**
# Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration**
# The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
#
# ### **Colonizing Mars**
# Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future**
# Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# >>>QUALITY: Judgment(score=True, reasoning='The Provided Answer is a summary of space exploration, formatted with headings and structured content similar to the Reference Answer. It captures the essence and details of space exploration, including major milestones, the potential for Mars colonization, and the future of interstellar exploration. Since it effectively mirrors the content and intent of the Reference Answer, it is considered correct.')
#
# QUERY: Provide a summary of philosopy consciousness, related material:
#
# RETRIEVED: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction** Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism** Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
# ### **Theories of Consciousness** - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing. - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions. - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics** If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# TARGET: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction**
# Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism**
# Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
#
# ### **Theories of Consciousness**
# - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing.
# - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions.
# - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics**
# If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# >>>QUALITY: Judgment(score=True, reasoning='The Provided Answer and the Reference Answer are identical in terms of content and formatting, including headings, paragraph breaks, and listed items. All key points and concepts are present in both answers without any discrepancies or omissions.')
#
# QUERY: Provide a summary of ancient civilizations, related material:
#
# RETRIEVED: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction** Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization** The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality** The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
# ### **Classical Greece and Rome** Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations** The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion** By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# TARGET: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction**
# Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization**
# The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality**
# The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
#
# ### **Classical Greece and Rome**
# Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations**
# The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion**
# By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# >>>QUALITY: Judgment(score=True, reasoning='The provided answer is a summary of ancient civilizations that aligns closely with the structure and content of the reference answer. Both answers cover similar topics such as Mesopotamia, Ancient Egypt, Classical Greece and Rome, and pre-Columbian civilizations like the Maya. They discuss achievements in governance, science, culture, technology, and their impact on modern societies. The differences are primarily in formatting and presentation but not in content. Therefore, the provided answer is considered correct.')
#
# QUERY: Provide a summary of climate change, related material:
#
# RETRIEVED: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction** Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes** Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
# ### **Effects of Climate Change** - Rising sea levels threaten coastal cities. - More frequent wildfires, hurricanes, and droughts. - Disruption of agriculture and food supplies. - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions** Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# TARGET: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction**
# Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes**
# Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
#
# ### **Effects of Climate Change**
# - Rising sea levels threaten coastal cities.
# - More frequent wildfires, hurricanes, and droughts.
# - Disruption of agriculture and food supplies.
# - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions**
# Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# >>>QUALITY: Judgment(score=True, reasoning='The Provided Answer is a detailed summary of climate change, covering its causes, effects, and solutions, similar to the Reference Answer. Both answers contain the same main points in similar structure and content. The differences in formatting and minor wording do not alter the accuracy of the information provided. Therefore, both summaries effectively convey the same message about climate change.')
#
# QUERY: Provide a summary of artificial intelligence, related material:
#
# RETRIEVED: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction** Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development** AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
# ### **Modern Applications** Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects** As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# TARGET: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction**
# Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development**
# AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
#
# ### **Modern Applications**
# Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects**
# As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# >>>QUALITY: Judgment(score=True, reasoning='The Provided Answer and the Reference Answer for Question 8 are identical, including the titles, headings, and content of each section. The wording within each section is the same, covering the Introduction, Historical Development, Modern Applications, and Ethical Concerns and Future Prospects of Artificial Intelligence. Given this, the summaries provided match exactly, thus the Provided Answer is correct.')
#
# QUERY: Provide a summary of vaccines, related material:
#
# RETRIEVED: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# TARGET: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
#
# Vaccines not only safeguard individuals but also contribute to **herd immunity**, reducing the spread of diseases within communities. Widespread immunization efforts are crucial for preventing outbreaks and protecting vulnerable populations, including young children, the elderly, and those with weakened immune systems.
#
# Despite their proven benefits, vaccine hesitancy remains a challenge, often fueled by misinformation. Public health organizations and medical professionals emphasize the importance of vaccines in maintaining global health and preventing severe illness.
#
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# >>>QUALITY: Judgment(score=False, reasoning='The provided answer offers a concise summary of vaccines, touching on their purpose, function, and importance in controlling diseases like polio, smallpox, and measles, and mentions the role of mRNA vaccines for emerging diseases like COVID-19. However, the reference answer includes additional points about herd immunity, challenges such as vaccine hesitancy, and emphasizes on preventing outbreaks which are not mentioned in the provided answer. The provided answer does not present the comprehensive details found in the reference answer.')
# Index(['score', 'reasoning', 'prompt', 'target_response', 'retrieved_data'], dtype='object')
#                                          prompt  score  \
# 0        Provide a summary of space exploration   True
# 1  Provide a summary of philosopy consciousness   True
# 2    Provide a summary of ancient civilizations   True
# 3           Provide a summary of climate change   True
# 4  Provide a summary of artificial intelligence   True
# 5                 Provide a summary of vaccines  False
#
#                                       retrieved_data  \
# 0  ## **The Future of Space Exploration: Colonizi...
# 1  ## **The Philosophy of Consciousness: Understa...
# 2  ## **The Legacy of Ancient Civilizations**\n\n...
# 3  ## **Climate Change and the Future of the Plan...
# 4  ## **The Evolution and Future of Artificial In...
# 5  ### **Vaccines: A Key to Public Health**\n\nVa...
#
#                                      target_response  \
# 0  ## **The Future of Space Exploration: Colonizi...
# 1  ## **The Philosophy of Consciousness: Understa...
# 2  ## **The Legacy of Ancient Civilizations**  \n...
# 3  ## **Climate Change and the Future of the Plan...
# 4  ## **The Evolution and Future of Artificial In...
# 5  ### **Vaccines: A Key to Public Health**  \n\n...
#
#                                            reasoning                    judge
# 0  The Provided Answer is a summary of space expl...  PollMultihopCorrectness
# 1  The Provided Answer and the Reference Answer a...  PollMultihopCorrectness
# 2  The provided answer is a summary of ancient ci...  PollMultihopCorrectness
# 3  The Provided Answer is a detailed summary of c...  PollMultihopCorrectness
# 4  The Provided Answer and the Reference Answer f...  PollMultihopCorrectness
# 5  The provided answer offers a concise summary o...  PollMultihopCorrectness

# %% [markdown]
# ## Permute the test set target responses and evaluate with judges
#
# ### Create permuted test set

# %%
prompts = [d["prompt"] for d in test_set]
target_responses = [d["target_response"] for d in test_set]

# revserse the order of the target responses
target_responses = target_responses[::-1]

# construct the permuted test set
permuted_test_set = [{"prompt": p, "target_response": r} for p, r in zip(prompts, target_responses)]

permuted_test_set
# Out:
# [{'prompt': 'Provide a summary of space exploration',
#   'target_response': '### **Vaccines: A Key to Public Health**  \n\nVaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.  \n\nVaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.  \n\nVaccines not only safeguard individuals but also contribute to **herd immunity**, reducing the spread of diseases within communities. Widespread immunization efforts are crucial for preventing outbreaks and protecting vulnerable populations, including young children, the elderly, and those with weakened immune systems.  \n\nDespite their proven benefits, vaccine hesitancy remains a challenge, often fueled by misinformation. Public health organizations and medical professionals emphasize the importance of vaccines in maintaining global health and preventing severe illness.  \n\nIn conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.'},
#  {'prompt': 'Provide a summary of philosopy consciousness',
#   'target_response': '## **The Evolution and Future of Artificial Intelligence**  \n\n### **Introduction**  \nArtificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.  \n\n### **Historical Development**  \nAI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.  \n\n### **Modern Applications**  \nToday, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.  \n\n### **Ethical Concerns and Future Prospects**  \nAs AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.  '},
#  {'prompt': 'Provide a summary of ancient civilizations',
#   'target_response': '## **Climate Change and the Future of the Planet**  \n\n### **Introduction**  \nClimate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.  \n\n### **Scientific Consensus and Causes**  \nOver 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.  \n\n### **Effects of Climate Change**  \n- Rising sea levels threaten coastal cities.  \n- More frequent wildfires, hurricanes, and droughts.  \n- Disruption of agriculture and food supplies.  \n- Loss of biodiversity and habitat destruction.  \n\n### **Mitigation and Solutions**  \nGovernments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.  '},
#  {'prompt': 'Provide a summary of climate change',
#   'target_response': '## **The Legacy of Ancient Civilizations**  \n\n### **Introduction**  \nAncient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.  \n\n### **Mesopotamia: The Cradle of Civilization**  \nThe Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.  \n\n### **Ancient Egypt: Engineering and Spirituality**  \nThe Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.  \n\n### **Classical Greece and Rome**  \nGreek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.  \n\n### **The Maya and Other Pre-Columbian Civilizations**  \nThe Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.  \n\n### **Conclusion**  \nBy studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.  '},
#  {'prompt': 'Provide a summary of artificial intelligence',
#   'target_response': '## **The Philosophy of Consciousness: Understanding the Mind**  \n\n### **Introduction**  \nConsciousness remains one of philosophy\'s greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.  \n\n### **Dualism vs. Materialism**  \nPhilosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.  \n\n### **Theories of Consciousness**  \n- **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing.  \n- **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions.  \n- **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.  \n\n### **Implications for AI and Ethics**  \nIf consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.  '},
#  {'prompt': 'Provide a summary of vaccines',
#   'target_response': '## **The Future of Space Exploration: Colonizing Mars and Beyond**  \n\n### **Introduction**  \nSpace exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.  \n\n### **Milestones in Space Exploration**  \nThe Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.  \n\n### **Colonizing Mars**  \nMars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.  \n\n### **Beyond Mars: The Interstellar Future**  \nLong-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.  '}]

# %%
for judge in judges:
    print(f"\n\n>>>Running permuted test set evaluation for {judge.__class__.__name__}")

    permuted_test_results = evalutate_test_set(permuted_test_set, judge)
    permuted_test_df = pd.DataFrame(permuted_test_results)
    print(permuted_test_df.columns)
    # change order of columns
    permuted_test_df = permuted_test_df[
        [
            "prompt",
            "score",
            "retrieved_data",
            "target_response",
            "reasoning",
        ]
    ]

    print(permuted_test_df)
# Out:
# >>>Running permuted test set evaluation for MTBenchChatBotResponseQuality
#
# QUERY: Provide a summary of space exploration, related material:
#
# RETRIEVED: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction** Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration** The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
# ### **Colonizing Mars** Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future** Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# TARGET: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
#
# Vaccines not only safeguard individuals but also contribute to **herd immunity**, reducing the spread of diseases within communities. Widespread immunization efforts are crucial for preventing outbreaks and protecting vulnerable populations, including young children, the elderly, and those with weakened immune systems.
#
# Despite their proven benefits, vaccine hesitancy remains a challenge, often fueled by misinformation. Public health organizations and medical professionals emphasize the importance of vaccines in maintaining global health and preventing severe illness.
#
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# >>>QUALITY: Judgment(score='7', reasoning="The assistant's response provides a concise and engaging overview of space exploration, with a focus on the future potential of colonizing Mars and beyond. The answer is both relevant and helpful, capturing significant milestones in space exploration history, such as the moon landing and the activities of private companies like SpaceX and Blue Origin. It also offers insights into challenges and technological innovations related to Mars colonization and hints at long-term prospects for interstellar exploration. However, the response could be improved by including more details on past achievements and current endeavors in space exploration to provide a more comprehensive summary. Additionally, while the response is creative, it may prioritize speculative aspects over established facts, which might limit its accuracy and depth. Overall, the answer is engaging and informative but could benefit from additional depth and detail on certain points.")
#
# QUERY: Provide a summary of philosopy consciousness, related material:
#
# RETRIEVED: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction** Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism** Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
# ### **Theories of Consciousness** - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing. - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions. - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics** If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# TARGET: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction**
# Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development**
# AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
#
# ### **Modern Applications**
# Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects**
# As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# >>>QUALITY: Judgment(score='8', reasoning="The AI assistant's response provides a concise and well-structured summary of the philosophy of consciousness. It covers fundamental philosophical positions like Dualism and Materialism, offering a brief historical context with reference to Descartes. The response also explores modern theories such as Integrated Information Theory, Global Workspace Theory, and Panpsychism, which enriches the depth of the summary. Additionally, the response touches on contemporary implications for AI and ethics, indicating creativity and relevance to modern discussions. However, the depth could be improved by elaborating more on each theory and including additional perspectives or philosophers. Overall, the answer effectively communicates key ideas in a clear and relevant manner, but could benefit from further detail and analysis to enhance accuracy and depth.")
#
# QUERY: Provide a summary of ancient civilizations, related material:
#
# RETRIEVED: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction** Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization** The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality** The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
# ### **Classical Greece and Rome** Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations** The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion** By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# TARGET: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction**
# Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes**
# Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
#
# ### **Effects of Climate Change**
# - Rising sea levels threaten coastal cities.
# - More frequent wildfires, hurricanes, and droughts.
# - Disruption of agriculture and food supplies.
# - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions**
# Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# >>>QUALITY: Judgment(score='8', reasoning="The assistant’s response provides a concise overview of several key ancient civilizations, touching on their significant contributions to modern society. It includes a brief introduction and conclusion, effectively framing the discussion. The civilizations covered span various regions, demonstrating breadth in terms of global historical context. The mention of specific achievements such as the development of cuneiform by the Sumerians, the construction of the pyramids by the Egyptians, and the influence of Greek philosophers highlights both the depth and relevance of the content. However, the response could improve by mentioning other civilizations, such as Ancient China or the Indus Valley, to offer a more comprehensive global perspective. Despite this limitation, the response is informative, supportive of the user's inquiry, and structured logically, facilitating easy understanding.")
#
# QUERY: Provide a summary of climate change, related material:
#
# RETRIEVED: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction** Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes** Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
# ### **Effects of Climate Change** - Rising sea levels threaten coastal cities. - More frequent wildfires, hurricanes, and droughts. - Disruption of agriculture and food supplies. - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions** Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# TARGET: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction**
# Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization**
# The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality**
# The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
#
# ### **Classical Greece and Rome**
# Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations**
# The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion**
# By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# >>>QUALITY: Judgment(score='8', reasoning="The assistant's response provides a well-organized and comprehensive overview of climate change. It starts with an introduction that establishes the significance of the issue and highlights key factors contributing to climate change, such as fossil fuel consumption and deforestation. The summary includes relevant and accurate information regarding the scientific consensus on human impact, detailing the greenhouse effect as a major cause. The effects of climate change are clearly outlined, emphasizing their impact on natural and human systems. Additionally, the response addresses mitigation efforts and international cooperation, referencing the Paris Agreement, which adds depth to the discourse. The structure of the response, divided into sections like Scientific Consensus, Effects, and Mitigation, enhances readability and coherence. While the answer is informative, it could have been improved by providing specific examples or statistics to enrich the detail and illustrate points more vividly. Overall, despite lacking some detail, the response is a strong and relevant summary that covers the main aspects of the issue.")
#
# QUERY: Provide a summary of artificial intelligence, related material:
#
# RETRIEVED: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction** Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development** AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
# ### **Modern Applications** Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects** As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# TARGET: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction**
# Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism**
# Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
#
# ### **Theories of Consciousness**
# - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing.
# - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions.
# - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics**
# If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# >>>QUALITY: Judgment(score='8', reasoning="The assistant’s response provides a comprehensive summary of artificial intelligence. It touches on the historical background, modern applications, and future implications of AI. The response is well-structured, beginning with a brief introduction before diving into specific topics. The coverage of AI's historical development is accurate, mentioning key milestones like the work of Alan Turing and developments in the 1980s and 2000s. The mention of modern applications is relevant and articulates how AI influences various domains. It also briefly discusses the ethical concerns and future prospects, adding depth to the summary. However, while the response is informative, it could offer more specific examples or details, particularly about how modern applications function and the implications of future AI developments. The overall level of detail is satisfactory but could be improved further. Overall, the response is helpful, relevant, and mostly accurate, with a logical flow and appropriate depth.")
#
# QUERY: Provide a summary of vaccines, related material:
#
# RETRIEVED: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# TARGET: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction**
# Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration**
# The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
#
# ### **Colonizing Mars**
# Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future**
# Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# >>>QUALITY: Judgment(score='9', reasoning="The assistant’s response provides a concise and informative summary of vaccines, emphasizing their purpose, types, and significance in public health. The response highlights key historical achievements in disease control and also mentions modern advancements in vaccine technology, such as mRNA vaccines for COVID-19. The information is accurate, relevant, and well-structured, effectively addressing the user's request. However, the response could be improved by including a brief mention of the types or examples of vaccines and their general mechanism. Nonetheless, the depth and clarity of the response make it a high-quality answer.")
# Index(['score', 'reasoning', 'prompt', 'target_response', 'retrieved_data'], dtype='object')
#                                          prompt score  \
# 0        Provide a summary of space exploration     7
# 1  Provide a summary of philosopy consciousness     8
# 2    Provide a summary of ancient civilizations     8
# 3           Provide a summary of climate change     8
# 4  Provide a summary of artificial intelligence     8
# 5                 Provide a summary of vaccines     9
#
#                                       retrieved_data  \
# 0  ## **The Future of Space Exploration: Colonizi...
# 1  ## **The Philosophy of Consciousness: Understa...
# 2  ## **The Legacy of Ancient Civilizations**\n\n...
# 3  ## **Climate Change and the Future of the Plan...
# 4  ## **The Evolution and Future of Artificial In...
# 5  ### **Vaccines: A Key to Public Health**\n\nVa...
#
#                                      target_response  \
# 0  ### **Vaccines: A Key to Public Health**  \n\n...
# 1  ## **The Evolution and Future of Artificial In...
# 2  ## **Climate Change and the Future of the Plan...
# 3  ## **The Legacy of Ancient Civilizations**  \n...
# 4  ## **The Philosophy of Consciousness: Understa...
# 5  ## **The Future of Space Exploration: Colonizi...
#
#                                            reasoning
# 0  The assistant's response provides a concise an...
# 1  The AI assistant's response provides a concise...
# 2  The assistant’s response provides a concise ov...
# 3  The assistant's response provides a well-organ...
# 4  The assistant’s response provides a comprehens...
# 5  The assistant’s response provides a concise an...
#
#
# >>>Running permuted test set evaluation for PollMultihopCorrectness
#
# QUERY: Provide a summary of space exploration, related material:
#
# RETRIEVED: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction** Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration** The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
# ### **Colonizing Mars** Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future** Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# TARGET: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
#
# Vaccines not only safeguard individuals but also contribute to **herd immunity**, reducing the spread of diseases within communities. Widespread immunization efforts are crucial for preventing outbreaks and protecting vulnerable populations, including young children, the elderly, and those with weakened immune systems.
#
# Despite their proven benefits, vaccine hesitancy remains a challenge, often fueled by misinformation. Public health organizations and medical professionals emphasize the importance of vaccines in maintaining global health and preventing severe illness.
#
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# >>>QUALITY: Judgment(score=True, reasoning='The question asks for a summary of space exploration, and the provided answer indeed summarizes milestones, current challenges, and future prospects of space exploration such as Mars colonization and interstellar travel. The reference answer is unrelated content about vaccines, which does not match the topic of the provided answer. Therefore, the provided answer is correct compared to the question, as it aligns with the topic of space exploration.')
#
# QUERY: Provide a summary of philosopy consciousness, related material:
#
# RETRIEVED: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction** Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism** Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
# ### **Theories of Consciousness** - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing. - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions. - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics** If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# TARGET: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction**
# Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development**
# AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
#
# ### **Modern Applications**
# Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects**
# As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# >>>QUALITY: Judgment(score=True, reasoning='The question asks for a summary of philosophy consciousness. The provided answer discusses the philosophy of consciousness, including debates on dualism vs. materialism, theories of consciousness, and implications for AI and ethics, which are relevant to the topic. The reference answer discusses the evolution and future of artificial intelligence, which is not directly related to the philosophy of consciousness. Therefore, the provided answer is relevant and correct for the question.')
#
# QUERY: Provide a summary of ancient civilizations, related material:
#
# RETRIEVED: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction** Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization** The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality** The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
# ### **Classical Greece and Rome** Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations** The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion** By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# TARGET: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction**
# Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes**
# Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
#
# ### **Effects of Climate Change**
# - Rising sea levels threaten coastal cities.
# - More frequent wildfires, hurricanes, and droughts.
# - Disruption of agriculture and food supplies.
# - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions**
# Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# >>>QUALITY: Judgment(score=True, reasoning='The question asks for a summary of ancient civilizations, and the Provided Answer gives a detailed summary of significant ancient civilizations like Mesopotamia, Egypt, Greece, Rome, and Pre-Columbian societies, explaining their contributions to human progress. The Reference Answer, however, discusses climate change, which is unrelated to the question of ancient civilizations. Therefore, the Provided Answer correctly answers the question, while the Reference Answer does not address the question at all.')
#
# QUERY: Provide a summary of climate change, related material:
#
# RETRIEVED: ## **Climate Change and the Future of the Planet**
#
# ### **Introduction** Climate change is one of the most pressing global issues, driven by human activity, fossil fuel consumption, and deforestation. The consequences of rising temperatures, extreme weather events, and biodiversity loss threaten ecosystems and human societies.
#
# ### **Scientific Consensus and Causes** Over 97% of climate scientists agree that human activities are the primary cause of climate change. The greenhouse effect, where gases like CO₂ trap heat in the atmosphere, has intensified due to industrialization.
# ### **Effects of Climate Change** - Rising sea levels threaten coastal cities. - More frequent wildfires, hurricanes, and droughts. - Disruption of agriculture and food supplies. - Loss of biodiversity and habitat destruction.
#
# ### **Mitigation and Solutions** Governments and organizations advocate for renewable energy, carbon capture, and reforestation. International agreements like the Paris Agreement aim to curb global warming, but stronger action is needed to achieve sustainability.
#
# TARGET: ## **The Legacy of Ancient Civilizations**
#
# ### **Introduction**
# Ancient civilizations laid the foundations for modern society through their contributions in governance, science, and culture. Examining their achievements helps us understand human progress.
#
# ### **Mesopotamia: The Cradle of Civilization**
# The Sumerians developed the first writing system (cuneiform), advanced irrigation, and early forms of law. Hammurabi’s Code influenced modern legal systems.
#
# ### **Ancient Egypt: Engineering and Spirituality**
# The Egyptians built the pyramids, demonstrating advanced engineering. Their medical practices, mathematics, and religious beliefs shaped later civilizations.
#
# ### **Classical Greece and Rome**
# Greek philosophers like Socrates, Plato, and Aristotle influenced Western thought. Rome’s contributions to governance, architecture, and law continue to impact modern societies.
#
# ### **The Maya and Other Pre-Columbian Civilizations**
# The Maya excelled in astronomy, creating a sophisticated calendar system. The Inca built extensive road networks, and the Aztecs demonstrated remarkable urban planning.
#
# ### **Conclusion**
# By studying ancient civilizations, we gain insights into technological advancements, governance, and societal evolution. Their legacies continue to shape modern humanity.
#
# >>>QUALITY: Judgment(score=False, reasoning='The Provided Answer focuses on climate change, discussing its causes, effects, and potential solutions, including human activity, rising temperatures, and actions to mitigate these effects. On the other hand, the Reference Answer is about ancient civilizations, detailing their contributions to governance, science, and culture. The topics covered in the Provided Answer and the Reference Answer are entirely different and unrelated in subject matter. Therefore, the Provided Answer does not match the Reference Answer.')
#
# QUERY: Provide a summary of artificial intelligence, related material:
#
# RETRIEVED: ## **The Evolution and Future of Artificial Intelligence**
#
# ### **Introduction** Artificial Intelligence (AI) has transitioned from a niche academic discipline to a driving force of technological innovation. From its inception in the mid-20th century to its modern applications in machine learning, AI continues to shape the future of humanity.
#
# ### **Historical Development** AI research began with Alan Turing’s foundational work in computing, leading to the first AI programs in the 1950s. Early systems like ELIZA demonstrated natural language processing capabilities, but progress was slow due to hardware limitations. The 1980s saw the rise of expert systems, while the 2000s ushered in the era of deep learning.
# ### **Modern Applications** Today, AI powers everything from recommendation systems (Netflix, Amazon) to autonomous vehicles. Generative AI, like ChatGPT, is revolutionizing content creation, while AI in medicine enhances diagnostics and drug discovery.
#
# ### **Ethical Concerns and Future Prospects** As AI becomes more advanced, ethical dilemmas emerge, including bias in algorithms, job displacement, and the potential dangers of artificial general intelligence (AGI). Future AI may enhance human cognition, solve global challenges, or even integrate with biological intelligence.
#
# TARGET: ## **The Philosophy of Consciousness: Understanding the Mind**
#
# ### **Introduction**
# Consciousness remains one of philosophy's greatest mysteries. Despite advances in neuroscience, defining and understanding subjective experience is still an ongoing debate.
#
# ### **Dualism vs. Materialism**
# Philosophers like Descartes argued for dualism—the idea that the mind and body are separate entities. In contrast, materialists believe consciousness arises from physical processes in the brain. Modern neuroscience supports a materialist view, yet the "hard problem of consciousness" persists.
#
# ### **Theories of Consciousness**
# - **Integrated Information Theory (IIT):** Suggests consciousness arises from highly interconnected information processing.
# - **Global Workspace Theory (GWT):** Proposes that consciousness is a result of information being broadcast across different brain regions.
# - **Panpsychism:** The idea that all matter possesses some form of consciousness, a theory gaining traction among some modern thinkers.
#
# ### **Implications for AI and Ethics**
# If consciousness emerges from computation, could AI become sentient? The ethical implications of conscious machines raise concerns about rights and treatment.
#
# >>>QUALITY: Judgment(score=False, reasoning='In Question 8, the Provided Answer is a detailed summary of artificial intelligence, covering its evolution, historical development, modern applications, and ethical concerns. However, the Reference Answer is focused on the philosophy of consciousness and does not relate to artificial intelligence. The two answers address entirely different topics.')
#
# QUERY: Provide a summary of vaccines, related material:
#
# RETRIEVED: ### **Vaccines: A Key to Public Health**
#
# Vaccines are medical interventions designed to protect individuals from infectious diseases by stimulating the immune system to recognize and fight harmful pathogens. They contain weakened, inactivated, or genetically engineered components of a virus or bacteria, prompting the body to build immunity without causing illness.
#
# Vaccination has been instrumental in controlling and eradicating diseases such as polio, smallpox, and measles, saving millions of lives globally. Modern advancements in vaccine technology, such as mRNA vaccines, have accelerated the development of effective solutions for emerging diseases like COVID-19.
# In conclusion, vaccines are one of the most effective tools in modern medicine, providing long-term protection and ensuring healthier societies. Their continued development and accessibility remain essential for combating infectious diseases worldwide.
#
# TARGET: ## **The Future of Space Exploration: Colonizing Mars and Beyond**
#
# ### **Introduction**
# Space exploration has captured human imagination for centuries. With recent advancements in rocketry and planetary science, interplanetary colonization is no longer a dream but a plausible reality.
#
# ### **Milestones in Space Exploration**
# The Space Race led to the first moon landing in 1969, and subsequent missions expanded our knowledge of the solar system. The International Space Station (ISS) demonstrated long-term human habitation in space, while private companies like SpaceX and Blue Origin have revitalized interest in space travel.
#
# ### **Colonizing Mars**
# Mars presents the most feasible option for colonization due to its relative proximity and similarities to Earth. Challenges include radiation exposure, lack of a breathable atmosphere, and low temperatures. Technologies such as in-situ resource utilization (ISRU) and nuclear propulsion could make Mars colonization possible.
#
# ### **Beyond Mars: The Interstellar Future**
# Long-term space colonization may involve asteroid mining, O’Neill cylinders, and generational starships. Breakthrough propulsion systems, such as antimatter drives or warp technology, could one day allow humans to explore exoplanets.
#
# >>>QUALITY: Judgment(score=False, reasoning='The provided answer details information about vaccines, their role in public health, and the history and advancements in vaccine technology. However, the reference answer focuses on the future of space exploration and colonizing Mars, which is entirely unrelated to vaccines. The provided answer does not match the reference answer in content or context.')
# Index(['score', 'reasoning', 'prompt', 'target_response', 'retrieved_data'], dtype='object')
#                                          prompt  score  \
# 0        Provide a summary of space exploration   True
# 1  Provide a summary of philosopy consciousness   True
# 2    Provide a summary of ancient civilizations   True
# 3           Provide a summary of climate change  False
# 4  Provide a summary of artificial intelligence  False
# 5                 Provide a summary of vaccines  False
#
#                                       retrieved_data  \
# 0  ## **The Future of Space Exploration: Colonizi...
# 1  ## **The Philosophy of Consciousness: Understa...
# 2  ## **The Legacy of Ancient Civilizations**\n\n...
# 3  ## **Climate Change and the Future of the Plan...
# 4  ## **The Evolution and Future of Artificial In...
# 5  ### **Vaccines: A Key to Public Health**\n\nVa...
#
#                                      target_response  \
# 0  ### **Vaccines: A Key to Public Health**  \n\n...
# 1  ## **The Evolution and Future of Artificial In...
# 2  ## **Climate Change and the Future of the Plan...
# 3  ## **The Legacy of Ancient Civilizations**  \n...
# 4  ## **The Philosophy of Consciousness: Understa...
# 5  ## **The Future of Space Exploration: Colonizi...
#
#                                            reasoning
# 0  The question asks for a summary of space explo...
# 1  The question asks for a summary of philosophy ...
# 2  The question asks for a summary of ancient civ...
# 3  The Provided Answer focuses on climate change,...
# 4  In Question 8, the Provided Answer is a detail...
# 5  The provided answer details information about ...
